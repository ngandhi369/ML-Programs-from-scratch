# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.array([1, 2, 3])
print(a,"\n")
b = np.array([[1, 2, 3], [4, 5, 6]])
print(b)

print(a[0], "\n")
print(a[1:], "\n")
print(b[0, 1], "\n")
print(b[:, 1:], "\n") 

a = np.array([1, 2, 3])
print(a,"\n")
b = a**2
print(b)

a = np.array([[1, 2], [3, 4]])
print(a,"\n")
b = np.array([[5, 6], [7, 8]])
print(b,"\n")
c = np.dot(a, b)
print(c)
# Out:
# [1 2 3]
#
# [[1 2 3]
#  [4 5 6]]
# 1
#
# [2 3]
#
# 2
#
# [[2 3]
#  [5 6]]
#
# [1 2 3]
#
# [1 4 9]
# [[1 2]
#  [3 4]]
#
# [[5 6]
#  [7 8]]
#
# [[19 22]
#  [43 50]]

# %%
a = np.array([1, 2, 3])
mean = np.mean(a)
median = np.median(a)
std_dev = np.std(a)
print(f'Mean:{mean}, Median:{median},Standard Deviation:{std_dev}')
# Out:
# Mean:2.0, Median:2.0,Standard Deviation:0.816496580927726

# %%
df=pd.read_csv('iris.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.sample(5)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 18  19            5.7           3.8            1.7           0.3
# 65  66            6.7           3.1            4.4           1.4
# 4    5            5.0           3.6            1.4           0.2
# 9   10            4.9           3.1            1.5           0.1
# 11  12            4.8           3.4            1.6           0.2
#
#             Species
# 18      Iris-setosa
# 65  Iris-versicolor
# 4       Iris-setosa
# 9       Iris-setosa
# 11      Iris-setosa

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df[2:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
df.iloc[2]
# Out:
# Id                         3
# SepalLengthCm            4.7
# SepalWidthCm             3.2
# PetalLengthCm            1.3
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 2, dtype: object

# %%
df.loc[df["Species"]=="Iris-setosa"]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df["PetalLengthCm"].sum()
# Out:
# 563.8

# %%
df["PetalLengthCm"].max()
# Out:
# 6.9

# %%
df["PetalLengthCm"].mean()
# Out:
# 3.758666666666666

# %%
df["PetalLengthCm"].std()
# Out:
# 1.7644204199522626

# %%
print(df[df['SepalLengthCm'] > 7.5].values)
df[df['SepalLengthCm'] > 7.5].count()
# Out:
# [[106 7.6 3.0 6.6 2.1 'Iris-virginica']
#  [118 7.7 3.8 6.7 2.2 'Iris-virginica']
#  [119 7.7 2.6 6.9 2.3 'Iris-virginica']
#  [123 7.7 2.8 6.7 2.0 'Iris-virginica']
#  [132 7.9 3.8 6.4 2.0 'Iris-virginica']
#  [136 7.7 3.0 6.1 2.3 'Iris-virginica']]
# Id               6
# SepalLengthCm    6
# SepalWidthCm     6
# PetalLengthCm    6
# PetalWidthCm     6
# Species          6
# dtype: int64

# %%
df.groupby('Species')['SepalLengthCm'].mean()
# Out:
# Species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64

# %%
sns.countplot(x='Species',data=df)
plt.show()

# %%
sns.countplot(x='SepalLengthCm',data=df)
plt.show()

# %%
df.plot(kind="scatter", x='SepalLengthCm', y='SepalWidthCm')
plt.show()# Without this warninigs is shown
# Out:
# C:\Users\Destiny\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
df.plot(kind="scatter", x='SepalLengthCm', y='PetalLengthCm', s=40, color="orange")
plt.show()

# %%
plt.plot(df['SepalLengthCm'], 'g+')
plt.show()

# %%
plt.plot(df['SepalLengthCm'])
plt.show()

# %%
plt.hist(df['SepalLengthCm'])
plt.show()

# %%
sns.histplot(df['SepalLengthCm'])
plt.show()

# %%
plt.hist(df['SepalLengthCm'], bins=25)
plt.show()

# %%
sns.histplot(df['SepalLengthCm'],bins=20)
plt.show()

# %%
sns.histplot(data = df['SepalLengthCm'], kde=True)
plt.show()

# %%
sns.FacetGrid(df, hue="Species", height=5).map(plt.scatter, "SepalLengthCm", "PetalLengthCm").add_legend()
plt.xlabel("Sepal Length (Cm)")
plt.ylabel("Petal Length (Cm)")
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm', y='PetalLengthCm', hue="Species", data=df)
plt.show()

# %% [markdown]
# ## Species Setosa has smaller petal lengths and widths.
# ## Versicolor Species lies in the middle of the other two species in terms of petal length and width
# ## Species Virginica has the largest of petal lengths and widths.

# %%
sns.boxplot(df['SepalLengthCm'])
plt.show()

# %%
sns.boxplot(x='Species', y='SepalLengthCm', data=df)
plt.show()

# %%
plt.subplot(121)
plt.plot(df.Id, df.PetalLengthCm)
plt.title("Petal Length")

plt.subplot(122)
plt.plot(df.Id, df.SepalLengthCm)
plt.title("Sepal Length")

plt.show()

# %%
df.sample(4)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 133  134            6.3           2.8            5.1           1.5
# 35    36            5.0           3.2            1.2           0.2
# 44    45            5.1           3.8            1.9           0.4
# 7      8            5.0           3.4            1.5           0.2
#
#             Species
# 133  Iris-virginica
# 35      Iris-setosa
# 44      Iris-setosa
# 7       Iris-setosa

# %%
sns.pairplot(df.drop(['Id'], axis=1), hue='Species')
# remove id from each row
plt.show()
